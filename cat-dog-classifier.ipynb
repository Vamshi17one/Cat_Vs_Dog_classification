# %%
import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense,Conv2D,MaxPooling2D,Flatten,BatchNormalization,Dropout
# Out:
# 2024-03-07 17:29:19.415969: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-07 17:29:19.416085: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-07 17:29:19.548463: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# generators
train_ds = keras.utils.image_dataset_from_directory(
    directory = '/kaggle/input/dogs-vs-cats/train',
    labels='inferred',
    label_mode = 'int',
    batch_size=32,
    image_size=(256,256)
)
# Out:
# Found 20000 files belonging to 2 classes.

# %%
validation_ds = keras.utils.image_dataset_from_directory(
    directory = '/kaggle/input/dogs-vs-cats/test',
    labels='inferred',
    label_mode = 'int',
    batch_size=32,
    image_size=(256,256)
)
# Out:
# Found 5000 files belonging to 2 classes.

# %%
# Normalize
def process(image,label):
    image = tf.cast(image/255. ,tf.float32)
    return image,label

train_ds = train_ds.map(process)
validation_ds = validation_ds.map(process)

# %%
# create CNN model

model = Sequential()

model.add(Conv2D(32,kernel_size=(3,3),padding='valid',activation='relu',input_shape=(256,256,3)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2),strides=2,padding='valid'))

model.add(Conv2D(64,kernel_size=(3,3),padding='valid',activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2),strides=2,padding='valid'))

model.add(Conv2D(128,kernel_size=(3,3),padding='valid',activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2),strides=2,padding='valid'))

model.add(Flatten())

model.add(Dense(128,activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(1,activation='sigmoid'))
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 254, 254, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 254, 254, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 127, 127, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 125, 125, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 125, 125, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 62, 62, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 60, 60, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 60, 60, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 30, 30, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 115200)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │    14,745,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,848,193 (56.64 MB)
#  Trainable params: 14,847,745 (56.64 MB)
#  Non-trainable params: 448 (1.75 KB)

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(train_ds,epochs=20,validation_data=validation_ds)
# Out:
# Epoch 1/20
# 2024-03-07 17:30:30.664518: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 5.22285, expected 4.50617
# 2024-03-07 17:30:30.664580: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 19: 4.83523, expected 4.11855
# 2024-03-07 17:30:30.664590: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 20: 6.14347, expected 5.42679
# 2024-03-07 17:30:30.664598: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 21: 5.72417, expected 5.00749
# 2024-03-07 17:30:30.664607: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 29: 6.00776, expected 5.29109
# 2024-03-07 17:30:30.664615: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 30: 5.39609, expected 4.67941
# 2024-03-07 17:30:30.664623: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 31: 5.14673, expected 4.43005
# 2024-03-07 17:30:30.664635: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 61: 5.93186, expected 5.21518
# 2024-03-07 17:30:30.664644: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 67: 6.09497, expected 5.3783
# 2024-03-07 17:30:30.664652: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 72: 4.9921, expected 4.27543
# 2024-03-07 17:30:30.695205: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[32,32,254,254]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,3,256,256]{3,2,1,0}, f32[32,3,3,3]{3,2,1,0}, f32[32]{0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=2,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-03-07 17:30:30.695261: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-03-07 17:30:30.695270: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-03-07 17:30:30.695277: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-03-07 17:30:30.695284: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-03-07 17:30:30.695301: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2024-03-07 17:30:31.593109: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 5.22285, expected 4.50617
# 2024-03-07 17:30:31.593169: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 19: 4.83523, expected 4.11855
# 2024-03-07 17:30:31.593178: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 20: 6.14347, expected 5.42679
# 2024-03-07 17:30:31.593185: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 21: 5.72417, expected 5.00749
# 2024-03-07 17:30:31.593193: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 29: 6.00776, expected 5.29109
# 2024-03-07 17:30:31.593201: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 30: 5.39609, expected 4.67941
# 2024-03-07 17:30:31.593208: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 31: 5.14673, expected 4.43005
# 2024-03-07 17:30:31.593216: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 61: 5.93186, expected 5.21518
# 2024-03-07 17:30:31.593223: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 67: 6.09497, expected 5.3783
# 2024-03-07 17:30:31.593231: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 72: 4.9921, expected 4.27543
# 2024-03-07 17:30:31.623109: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[32,32,254,254]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,3,256,256]{3,2,1,0}, f32[32,3,3,3]{3,2,1,0}, f32[32]{0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=2,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-03-07 17:30:31.623181: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-03-07 17:30:31.623190: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-03-07 17:30:31.623198: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-03-07 17:30:31.623205: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-03-07 17:30:31.623222: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
#   3/625 ━━━━━━━━━━━━━━━━━━━━ 28s 45ms/step - accuracy: 0.5087 - loss: 2.2218
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1709832639.311249     112 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.5799 - loss: 2.0840
# 2024-03-07 17:31:19.175056: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 129032: 6.56968, expected 5.72998
# 2024-03-07 17:31:19.175127: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 129051: 7.10358, expected 6.26388
# 2024-03-07 17:31:19.175141: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 129052: 6.99086, expected 6.15116
# 2024-03-07 17:31:19.175154: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 129062: 7.37213, expected 6.53244
# 2024-03-07 17:31:19.175169: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 129063: 6.0521, expected 5.2124
# 2024-03-07 17:31:19.175184: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 129064: 7.1427, expected 6.30301
# 2024-03-07 17:31:19.175194: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 129072: 7.38607, expected 6.54637
# 2024-03-07 17:31:19.175205: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 129098: 7.18015, expected 6.34045
# 2024-03-07 17:31:19.175216: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 129104: 7.04205, expected 6.20235
# 2024-03-07 17:31:19.175226: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 129105: 7.05266, expected 6.21296
# 2024-03-07 17:31:19.182965: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[8,32,254,254]{3,2,1,0}, u8[0]{0}) custom-call(f32[8,3,256,256]{3,2,1,0}, f32[32,3,3,3]{3,2,1,0}, f32[32]{0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=2,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-03-07 17:31:19.183010: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-03-07 17:31:19.183022: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-03-07 17:31:19.183033: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-03-07 17:31:19.183049: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-03-07 17:31:19.183089: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2024-03-07 17:31:19.403051: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 129032: 6.56968, expected 5.72998
# 2024-03-07 17:31:19.403144: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 129051: 7.10358, expected 6.26388
# 2024-03-07 17:31:19.403159: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 129052: 6.99086, expected 6.15116
# 2024-03-07 17:31:19.403178: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 129062: 7.37213, expected 6.53244
# 2024-03-07 17:31:19.403190: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 129063: 6.0521, expected 5.2124
# 2024-03-07 17:31:19.403201: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 129064: 7.1427, expected 6.30301
# 2024-03-07 17:31:19.403211: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 129072: 7.38607, expected 6.54637
# 2024-03-07 17:31:19.403222: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 129098: 7.18015, expected 6.34045
# 2024-03-07 17:31:19.403232: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 129104: 7.04205, expected 6.20235
# 2024-03-07 17:31:19.403242: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 129105: 7.05266, expected 6.21296
# 2024-03-07 17:31:19.410661: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[8,32,254,254]{3,2,1,0}, u8[0]{0}) custom-call(f32[8,3,256,256]{3,2,1,0}, f32[32,3,3,3]{3,2,1,0}, f32[32]{0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=2,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-03-07 17:31:19.410709: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-03-07 17:31:19.410733: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-03-07 17:31:19.410747: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-03-07 17:31:19.410761: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-03-07 17:31:19.410780: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 56s 66ms/step - accuracy: 0.5800 - loss: 2.0825 - val_accuracy: 0.6698 - val_loss: 0.6695
# Epoch 2/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 32s 50ms/step - accuracy: 0.6808 - loss: 0.5926 - val_accuracy: 0.6826 - val_loss: 0.6101
# Epoch 3/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 32s 51ms/step - accuracy: 0.7382 - loss: 0.5264 - val_accuracy: 0.7618 - val_loss: 0.5377
# Epoch 4/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 32s 50ms/step - accuracy: 0.7721 - loss: 0.4759 - val_accuracy: 0.7660 - val_loss: 0.4906
# Epoch 5/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 32s 50ms/step - accuracy: 0.8013 - loss: 0.4285 - val_accuracy: 0.7846 - val_loss: 0.5863
# Epoch 6/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 32s 50ms/step - accuracy: 0.8235 - loss: 0.3840 - val_accuracy: 0.7900 - val_loss: 0.4908
# Epoch 7/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 32s 50ms/step - accuracy: 0.8526 - loss: 0.3328 - val_accuracy: 0.7972 - val_loss: 0.5464
# Epoch 8/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 32s 50ms/step - accuracy: 0.8858 - loss: 0.2643 - val_accuracy: 0.7968 - val_loss: 0.7324
# Epoch 9/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 32s 50ms/step - accuracy: 0.9208 - loss: 0.1930 - val_accuracy: 0.7982 - val_loss: 0.6924
# Epoch 10/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 32s 51ms/step - accuracy: 0.9418 - loss: 0.1549 - val_accuracy: 0.7818 - val_loss: 1.2171
# Epoch 11/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 32s 50ms/step - accuracy: 0.9585 - loss: 0.1177 - val_accuracy: 0.7864 - val_loss: 0.8930
# Epoch 12/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 32s 50ms/step - accuracy: 0.9666 - loss: 0.0874 - val_accuracy: 0.7742 - val_loss: 1.2344
# Epoch 13/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 32s 50ms/step - accuracy: 0.9701 - loss: 0.0909 - val_accuracy: 0.7792 - val_loss: 1.6433
# Epoch 14/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 32s 50ms/step - accuracy: 0.9787 - loss: 0.0671 - val_accuracy: 0.7630 - val_loss: 3.5464
# Epoch 15/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 32s 50ms/step - accuracy: 0.9838 - loss: 0.0474 - val_accuracy: 0.7964 - val_loss: 1.8774
# Epoch 16/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 32s 50ms/step - accuracy: 0.9874 - loss: 0.0365 - val_accuracy: 0.7298 - val_loss: 2.1409
# Epoch 17/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 32s 50ms/step - accuracy: 0.9853 - loss: 0.0470 - val_accuracy: 0.8008 - val_loss: 1.7380
# Epoch 18/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 32s 50ms/step - accuracy: 0.9854 - loss: 0.0433 - val_accuracy: 0.7876 - val_loss: 1.1997
# Epoch 19/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 32s 50ms/step - accuracy: 0.9903 - loss: 0.0326 - val_accuracy: 0.7722 - val_loss: 2.1343
# Epoch 20/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 32s 50ms/step - accuracy: 0.9901 - loss: 0.0309 - val_accuracy: 0.8012 - val_loss: 2.2273

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'],color='red',label='train')
plt.plot(history.history['val_accuracy'],color='blue',label='validation')
plt.legend()
plt.show()

# %%
plt.plot(history.history['accuracy'],color='red',label='train')
plt.plot(history.history['val_accuracy'],color='blue',label='validation')
plt.legend()
plt.show()

# %%
plt.plot(history.history['loss'],color='red',label='train')
plt.plot(history.history['val_loss'],color='blue',label='validation')
plt.legend()
plt.show()

# %%
plt.plot(history.history['loss'],color='red',label='train')
plt.plot(history.history['val_loss'],color='blue',label='validation')
plt.legend()
plt.show()

# %%
import cv2
test_img = cv2.imread('/kaggle/input/catimage-jpg/cat_image1.jpeg')
plt.imshow(test_img)

# %%
test_img.shape
# Out:
# (224, 225, 3)

# %%
test_img = cv2.resize(test_img,(256,256))

# %%
test_input = test_img.reshape((1,256,256,3))

# %%
model.predict(test_input)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# array([[0.]], dtype=float32)
